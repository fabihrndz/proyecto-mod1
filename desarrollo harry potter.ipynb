# %%
ataque={
    "expelliarmus":5,
    "petrificus totalus":4,
    "imperio":7,
    "reducto":8,
    "crucio":8,
    "avada Kedavra":15,
    "sectumsempra":10
}

# %%
defensa={
    "repello":5,
    "expecto patronum":15,
    "expelliarmus":6,
    "stupefy":4,
    "inpedimenta":8,
    "incarcerous":7
}
