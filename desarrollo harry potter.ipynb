# %%
ataque={
    "expelliarmus":5,
    "petrificus totalus":4,
    "imperio":7,
    "reducto":8,
    "crucio":8,
    "avada Kedavra":15,
    "sectumsempra":10
}

# %%
defensa={
    "repello":5,
    "expecto patronum":15,
    "expelliarmus":6,
    "stupefy":4,
    "inpedimenta":8,
    "incarcerous":7
}

# %% [markdown]
# una vez que tenemos definidos los hechizos de ataque y defensa procedemos a definir la manera de atacar

# %%
#creamos a los jugadores.
jugador1= input("elige un nombre").lower()

# %%
#preguntamos al jugador si quiere atacar o defender
hechizo=input("quieres atacar o quieres defender").lower()

# %%
if hechizo in ataque:
    for a in ataque.random(ataque):
        print(a)
