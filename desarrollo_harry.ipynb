# %%
import random

# %%
# Para contar los puntos
contador1 = 0
contador2 = 0

# %%
# Creamos los hechizos
a=[
    "expelliarmus",
    "petrificus totalus",
    "imperio",
    "reducto",
    "crucio",
    "avada Kedavra",
    "sectumsempra",]

# %%
d=[
    "repello",
    "expecto patronum",
    "expelliarmus",
    "stupefy",
    "inpedimenta",
    "incarcerous"
]

# %%
# Crear a los jugadores
jugador1 = input("Escribe tu nombre:")
jugador2 = input("Escribe tu nombre")

# %%
while True:
    turno = "jugador1"
    if turno == "jugador1":
        hechizo = input(f" {jugador1} Quieres atacar(A) o defender(D)").lower()
        if hechizo ==  "a":
            hechizo = random.choice(a)
            valores = random.randint(1,15)
            contador2 -= valores
            print(f"Hechizo: {hechizo}, Daño: {valores}, {jugador2}: {contador2} \n {jugador1}:{contador1} \n {jugador2}:{contador2}")
        else:
            hechizo = random.choice(d)
            valores = random.randint(1,15)
            contador1 += valores
            print(f"Hechizo: {hechizo}, Vida: {valores}, {jugador1}: {contador1} \n {jugador1}:{contador1} \n {jugador2}:{contador2}")
        turno = "jugador2"
    elif turno == "jugador2":
        hechizo = input(f" {jugador2} Quieres atacar(A) o defender(D)").lower()
        if hechizo ==  "a":
            hechizo = random.choice(a)
            valores = random.randint(1,15)
            contador1 -= valores
            print(f"Hechizo: {hechizo}, Daño: {valores}, {jugador1}: {contador1} \n {jugador1}:{contador1} \n {jugador2}:{contador2}")
        else:
            hechizo = random.choice(d)
            valores = random.randint(1,15)
            contador2 += valores
            print(f"Hechizo: {hechizo}, Vida: {valores}, {jugador2}: {contador2} \n {jugador1}:{contador1} \n {jugador2}:{contador2}")
        turno = "jugador1"
        if contador1 >= 50:
            print(f"Gana {jugador1}")
            break
        elif contador2 >= 50:
            print(f"Gana {jugador2}")
            break
# Out:
# Hechizo: avada Kedavra, Daño: 4, sara: -4
#  fabi:0
#  sara:-4
# Hechizo: imperio, Daño: 5, sara: -9
#  fabi:0
#  sara:-9
# Hechizo: avada Kedavra, Daño: 15, sara: -24
#  fabi:0
#  sara:-24
# Hechizo: avada Kedavra, Daño: 10, sara: -34
#  fabi:0
#  sara:-34
# Hechizo: reducto, Daño: 15, sara: -49
#  fabi:0
#  sara:-49
# Hechizo: avada Kedavra, Daño: 1, sara: -50
#  fabi:0
#  sara:-50
# Hechizo: incarcerous, Vida: 5, fabi: 5
#  fabi:5
#  sara:-50
# Hechizo: stupefy, Vida: 10, fabi: 15
#  fabi:15
#  sara:-50
# Hechizo: inpedimenta, Vida: 3, fabi: 18
#  fabi:18
#  sara:-50
# Hechizo: inpedimenta, Vida: 3, fabi: 21
#  fabi:21
#  sara:-50
# Hechizo: stupefy, Vida: 2, fabi: 23
#  fabi:23
#  sara:-50
# Hechizo: incarcerous, Vida: 5, fabi: 28
#  fabi:28
#  sara:-50
# Hechizo: inpedimenta, Vida: 6, fabi: 34
#  fabi:34
#  sara:-50
# Hechizo: inpedimenta, Vida: 7, fabi: 41
#  fabi:41
#  sara:-50
# Hechizo: expecto patronum, Vida: 7, fabi: 48
#  fabi:48
#  sara:-50
# ...
