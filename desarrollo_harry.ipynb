# %%
import random

# %%
#creamos a los jugadores.
contador1 = 0
contador2 = 0

# %%
a=[
    "expelliarmus",
    "petrificus totalus",
    "imperio",
    "reducto",
    "crucio",
    "avada Kedavra",
    "sectumsempra",]

# %%
d=[
    "repello",
    "expecto patronum",
    "expelliarmus",
    "stupefy",
    "inpedimenta",
    "incarcerous"
]

# %%
jugador1 = input("Escribe tu nombre:")
jugador2 = input("Escribe tu nombre")

hechizo1 = input("Quieres atacar(A) o defender(D)").lower()
jugador2 = input("Quieres atacar(A) o defender(D)").lower()

# %%
if hechizo1 ==  "a":
    hechizo = random.choice(a)
    valores = random.randint(1,15)
    contador2 -= valores
    print(f"Hechizo: {hechizo}, Daño: {valores}, {jugador2}: {contador2}")
# Out:
# Hechizo: reducto, Daño: 14, a: -14
