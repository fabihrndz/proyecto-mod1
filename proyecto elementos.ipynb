# %% [markdown]
# normas del juego:
# 3 elementos: aire,fuego,tierra:
# agua es ==agua empate
# opciones de ganar:
# el agua gana a fuego, el fuego gana a tierra, tierrra gana a agua

# %%
jugador1="agua"
jugador2="fuego"

# %%
if jugador1== jugador2:
    print("empate")
elif (jugador1=="agua"and jugador2=="fuego") or (jugador1=="fuego" and jugador2=="tierra") or (jugador1=="tierra"and jugador2"agua"):
    print("gana jugador 1")
else: 
    print("perdiste")
# Out:
#   Cell In[5], line 3
#     elif (jugador1=="agua"and jugador2=="fuego") or (jugador1=="fuego" and jugador2=="tierra") or (jugador1=="tierra"and jugador2"agua"):
#                                                                                                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
