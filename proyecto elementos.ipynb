# %% [markdown]
# Elementos /variables:
# 	aire , fuego, agua , tierra
#     Condiciones:
# 	agua gana  fuego
# 	fuego gana aire
# 	aire gana tierra
# 	tierra gana fuego.

# %%
jug1 = "aire"
jug2 = input ("aire","fuego","tierra","agua")
if jug1 == "aire":
    if jug2=="fuego":
        print( "gana jug2")
    elif jug2 == "tierra":
        print ("gana jugador 1")
    elif jug2 == "papel":
        print("gana jug1")
    else:
        print("algo falla")
